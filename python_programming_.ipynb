# %% [markdown]
# <a href="https://colab.research.google.com/github/aswinss949/ICT-BATCH-9/blob/main/python_programming_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #word frequency analyser

# %%
from typing import Text
import re
from collections import Counter

def top_k_words(filename: str, k: int) -> list:
    #read file content
    with open(filename,'r')as f:
      text = f.read()
    # converting to lower case and igonre punctuation
    words = re.findall(r'\b\w+\b',text.lower())
    freq = Counter(words)
    #sorting by descending then alphabatically
    sorted_words = sorted(freq.items(), key=lambda x: (-x[1], x[0]))
    return [word for word, count in sorted_words[:k]]


# Sample Test (create a sample file)
with open("sample.txt", "w") as f:
    f.write("Data science is evolving. Python is versatile. Learning never stops.")

print(top_k_words("sample.txt", 3))  #expected ["is", "data", "science"]

# %% [markdown]
# #analyse daily expence and extract insights

# %%
def analyze_expenses():
    n = int(input("Enter number of transactions: "))

    expenses = {}

    for _ in range(n):
        category, amount = input().split()
        amount = float(amount)

        # Store category-wise total
        if category in expenses:
            expenses[category] += amount
        else:
            expenses[category] = amount

    # Calculate total expense
    total = sum(expenses.values())

    # Find highest expense category
    highest_category = max(expenses, key=expenses.get)

    print("Total Expense:", total)
    print("Highest Category:", highest_category)
    print("Category-wise:", expenses)


analyze_expenses()

# %% [markdown]
# # Challenge 3: Data Cleaner (Mini Pandas Logic Without Pandas)

# %%
def clean_data():
    n = int(input("Enter number of values: "))

    data = []

    for _ in range(n):
        value = input().strip()

        try:
            num = float(value)

            # Ignore negative values
            if num < 0:
                continue

            data.append(num)

        except:
            # handling invalid values
            continue


    if len(data) == 0:
        avg = 0
        max_val = None
    else:
        # Calculate average
        avg = sum(data) / len(data)

        # Find max value
        max_val = max(data)

    print("Clean Data:", data)
    print("Average:", avg)
    print("Max:", max_val)



clean_data()
